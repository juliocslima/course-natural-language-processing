# %%
# Importing the data files
# !wget -nc https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/edgar_allan_poe.txt
# !wget -nc https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Out:
# --2022-06-15 10:53:04--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/edgar_allan_poe.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26622 (26K) [text/plain]
# Saving to: ‘edgar_allan_poe.txt’
#
# edgar_allan_poe.txt 100%[===================>]  26,00K  --.-KB/s    in 0,02s
#
# 2022-06-15 10:53:05 (1,03 MB/s) - ‘edgar_allan_poe.txt’ saved [26622/26622]
#
# --2022-06-15 10:53:05--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56286 (55K) [text/plain]
# Saving to: ‘robert_frost.txt’
#
# robert_frost.txt    100%[===================>]  54,97K  --.-KB/s    in 0,1s
#
# 2022-06-15 10:53:06 (390 KB/s) - ‘robert_frost.txt’ saved [56286/56286]

# %%
import numpy as np
import matplotlib.pyplot as plt
import string
from sklearn.model_selection import train_test_split

# %%
input_files = [
    'edgar_allan_poe.txt',
    'robert_frost.txt',
]

# %%
# !head edgar_allan_poe.txt
# Out:
# LO! Death hath rear'd himself a throne
# In a strange city, all alone,
# Far down within the dim west
# Where the good, and the bad, and the worst, and the best,
# Have gone to their eternal rest.
#
# There shrines, and palaces, and towers
# Are not like any thing of ours
# Oh no! O no! ours never loom
# To heaven with that ungodly gloom!

# %%
# !head robert_frost.txt
# Out:
# Two roads diverged in a yellow wood,
# And sorry I could not travel both
# And be one traveler, long I stood
# And looked down one as far as I could
# To where it bent in the undergrowth;
#
# Then took the other, as just as fair,
# And having perhaps the better claim
# Because it was grassy and wanted wear,
# Though as for that the passing there

# %%
# collect data into lists
input_texts = []
labels = []

for label, f in enumerate(input_files):
    print(f'{f} corresponds to label {label}')
    
    for line in open(f):
        line = line.rstrip().lower()
        if line:
            # remove the punctuation
            line = line.translate(str.maketrans('', '', string.punctuation))
            
            input_texts.append(line)
            labels.append(label)
# Out:
# edgar_allan_poe.txt corresponds to label 0
# robert_frost.txt corresponds to label 1

# %%
train_text, test_text, y_train, y_test = train_test_split(input_texts, labels)

# %%
len(y_train), len(y_test)
# Out:
# (1615, 539)

# %%
train_text[:5]
# Out:
# ['the attic wasps went missing by like bullets',
#  'that need endless talktalk',
#  '2o3 let them stay in the attic since they went there',
#  'someones road home from work this once was',
#  'with stone and lead to unprotected glass']

# %%
y_train[:5]
# Out:
# [1, 1, 1, 1, 1]

# %%
idx = 1
word2idx = {'<unk>': 0}

# %%
# populate word2idx
for text in train_text:
    tokens = text.split()
    for token in tokens:
        if token not in word2idx:
            word2idx[token] = idx
            idx += 1

# %%
word2idx
# Out:
# {'<unk>': 0,
#  'the': 1,
#  'attic': 2,
#  'wasps': 3,
#  'went': 4,
#  'missing': 5,
#  'by': 6,
#  'like': 7,
#  'bullets': 8,
#  'that': 9,
#  'need': 10,
#  'endless': 11,
#  'talktalk': 12,
#  '2o3': 13,
#  'let': 14,
#  'them': 15,
#  'stay': 16,
#  'in': 17,
#  'since': 18,
#  'they': 19,
#  'there': 20,
#  'someones': 21,
#  'road': 22,
#  'home': 23,
#  'from': 24,
#  'work': 25,
#  'this': 26,
#  'once': 27,
#  'was': 28,
#  'with': 29,
#  'stone': 30,
#  'and': 31,
#  'lead': 32,
#  'to': 33,
#  'unprotected': 34,
#  'glass': 35,
#  'a': 36,
#  'tree': 37,
#  'had': 38,
#  'been': 39,
#  'down': 40,
#  'raised': 41,
#  'again—': 42,
#  'bill': 43,
#  'doesnt': 44,
#  'exist': 45,
#  'if': 46,
#  'id': 47,
#  'left': 48,
#  'him': 49,
#  'hitched': 50,
#  'unblanketed': 51,
#  'you': 52,
#  'must': 53,
#  'be': 54,
#  'very': 55,
#  'still': 56,
#  'mustnt': 57,
#  'talk': 58,
#  'of': 59,
#  'tower': 60,
#  'clock': 61,
#  'bade': 62,
#  'me': 63,
#  'pause': 64,
#  'before': 65,
#  'gardengate': 66,
#  'hes': 67,
#  'after': 68,
#  'an': 69,
#  'open': 70,
#  'door': 71,
#  'get': 72,
#  'outdoors': 73,
#  'i': 74,
#  'cried': 75,
#  'it': 76,
#  'surely': 77,
#  'october': 78,
#  'estelles': 79,
#  'take': 80,
#  'when': 81,
#  'shes': 82,
#  'settled': 83,
#  'no': 84,
#  'one': 85,
#  'way': 86,
#  'only': 87,
#  'house': 88,
#  'faintest': 89,
#  'restless': 90,
#  'rustling': 91,
#  'ran': 92,
#  'all': 93,
#  'through': 94,
#  'some': 95,
#  'money': 96,
#  'suddenly': 97,
#  'come': 98,
#  'into': 99,
#  'go': 100,
#  'west': 101,
#  'worse': 102,
#  'fight': 103,
#  'desert': 104,
#  'so': 105,
#  'as': 106,
#  'sort': 107,
#  'turn': 108,
#  'out': 109,
#  'we': 110,
#  'trod': 111,
#  'uncomfortably': 112,
#  'on': 113,
#  'crunching': 114,
#  'well': 115,
#  'then': 116,
#  'right': 117,
#  'here': 118,
#  'is': 119,
#  'where': 120,
#  'show': 121,
#  'books': 122,
#  'their': 123,
#  'solemn': 124,
#  'peals': 125,
#  'more': 126,
#  'salt': 127,
#  'wherewith': 128,
#  'theyre': 129,
#  'salted': 130,
#  'oh': 131,
#  'thats': 132,
#  'for': 133,
#  'hawks': 134,
#  'chickentime': 135,
#  'she': 136,
#  'thinks': 137,
#  'bad': 138,
#  'live': 139,
#  'perhaps': 140,
#  'may': 141,
#  'my': 142,
#  'mind': 143,
#  'wrought': 144,
#  'sovereignty': 145,
#  'than': 146,
#  'ancient': 147,
#  'lore': 148,
#  'birds': 149,
#  'joined': 150,
#  'excited': 151,
#  'fun': 152,
#  'both': 153,
#  'either': 154,
#  'looking': 155,
#  'or': 156,
#  'finding': 157,
#  'something': 158,
#  'but': 159,
#  'leaf': 160,
#  'lingered': 161,
#  'brown': 162,
#  'earnest': 163,
#  'appears': 164,
#  'between': 165,
#  'north': 166,
#  'pole—': 167,
#  'moisture': 168,
#  'color': 169,
#  'odor': 170,
#  'thicken': 171,
#  'its': 172,
#  'own': 173,
#  'fervor': 174,
#  'what': 175,
#  'oer': 176,
#  'power': 177,
#  'wasted': 178,
#  'snow': 179,
#  'got': 180,
#  'up': 181,
#  'do': 182,
#  'anything': 183,
#  'which': 184,
#  'he': 185,
#  'sits': 186,
#  'sings': 187,
#  'strapping': 188,
#  'girl': 189,
#  'twenty': 190,
#  'ive': 191,
#  'said': 192,
#  'why': 193,
#  'shouldnt': 194,
#  'married': 195,
#  'furs': 196,
#  'sell': 197,
#  'not': 198,
#  'lupine': 199,
#  'living': 200,
#  'sand': 201,
#  'drouth': 202,
#  'see': 203,
#  'flickers': 204,
#  'sky': 205,
#  'night': 206,
#  'at': 207,
#  'end': 208,
#  'our': 209,
#  'path': 210,
#  'liquescent': 211,
#  'tamed': 212,
#  'primeval': 213,
#  'wood': 214,
#  'pauses': 215,
#  'heaven': 216,
#  'seraphic': 217,
#  'glancing': 218,
#  'thine': 219,
#  'eyes': 220,
#  'will': 221,
#  'leave': 222,
#  'yes': 223,
#  'thy': 224,
#  'dear': 225,
#  'name': 226,
#  'text': 227,
#  'though': 228,
#  'bidden': 229,
#  'thee': 230,
#  'being': 231,
#  'invisible': 232,
#  'misting': 233,
#  'lets': 234,
#  'fair': 235,
#  'unfortunately': 236,
#  'kind': 237,
#  'blandishments': 238,
#  'would': 239,
#  'seem': 240,
#  'defied': 241,
#  'how': 242,
#  'often': 243,
#  'forget': 244,
#  'time': 245,
#  'lone': 246,
#  'ought': 247,
#  'give': 248,
#  'purer': 249,
#  'oracle': 250,
#  'mother': 251,
#  'never': 252,
#  'son': 253,
#  'windbreak': 254,
#  'two': 255,
#  'miles': 256,
#  'his': 257,
#  'abode': 258,
#  'blotting': 259,
#  'utterly': 260,
#  'high': 261,
#  'have': 262,
#  'art': 263,
#  'mean': 264,
#  'trees': 265,
#  'grow': 266,
#  'short': 267,
#  'mosses': 268,
#  'tall': 269,
#  'except': 270,
#  'always': 271,
#  'johnjoe': 272,
#  'lost': 273,
#  'himself': 274,
#  'tongue': 275,
#  'fire': 276,
#  'hand': 277,
#  'buttonbox': 278,
#  'smoke': 279,
#  'rolled': 280,
#  'inside': 281,
#  'sockets': 282,
#  'spirit': 283,
#  'communing': 284,
#  'angels': 285,
#  'long': 286,
#  'lay': 287,
#  'full': 288,
#  'sit': 289,
#  'dark': 290,
#  'say': 291,
#  'saw': 292,
#  'unless': 293,
#  'stove': 294,
#  'found': 295,
#  'hed': 296,
#  'gnawed': 297,
#  'four': 298,
#  'posts': 299,
#  'bed': 300,
#  'daylight': 301,
#  'beauty': 302,
#  'birth': 303,
#  'having': 304,
#  'interfered': 305,
#  'huse': 306,
#  'business': 307,
#  'barn': 308,
#  'smells': 309,
#  'cant': 310,
#  'wash': 311,
#  'ploughed': 312,
#  'ground': 313,
#  'theres': 314,
#  'dite': 315,
#  'too': 316,
#  'many': 317,
#  'comfort': 318,
#  'her': 319,
#  'hardest': 320,
#  'hue': 321,
#  'hold': 322,
#  'stood': 323,
#  'stopped': 324,
#  'sound': 325,
#  'feet': 326,
#  'spoke': 327,
#  'prove': 328,
#  'years': 329,
#  'girdle': 330,
#  'mark': 331,
#  'threshold': 332,
#  'wideopen': 333,
#  'gate': 334,
#  'dreams': 335,
#  'fullorbed': 336,
#  'moon': 337,
#  'soul': 338,
#  'soaring': 339,
#  'winter': 340,
#  'garden': 341,
#  'alder': 342,
#  'swamp': 343,
#  'fell': 344,
#  'upturnd': 345,
#  'faces': 346,
#  'roses': 347,
#  'coming': 348,
#  'ryans': 349,
#  'hill': 350,
#  'thought': 351,
#  'twas': 352,
#  'beside': 353,
#  'trade': 354,
#  'front': 355,
#  'others': 356,
#  'wriggling': 357,
#  'speed': 358,
#  'particular': 359,
#  'oclock': 360,
#  'supposed': 361,
#  'mad': 362,
#  'town': 363,
#  'know': 364,
#  'raining': 365,
#  'dont': 366,
#  'myself': 367,
#  'john': 368,
#  'replied': 369,
#  'nothing': 370,
#  'dreaming': 371,
#  'love': 372,
#  'forgot': 373,
#  'cottages': 374,
#  'row': 375,
#  'does': 376,
#  'because': 377,
#  'likes': 378,
#  'steps': 379,
#  'began': 380,
#  'climb': 381,
#  'stairs': 382,
#  'harmless': 383,
#  'hears': 384,
#  'quenching': 385,
#  'fires': 386,
#  'ashes': 387,
#  'hide': 388,
#  'becoming': 389,
#  'reconciled': 390,
#  'rolls': 391,
#  'ether': 392,
#  'sighs': 393,
#  'playthings': 394,
#  'playhouse': 395,
#  'children': 396,
#  'wave': 397,
#  'ripple': 398,
#  'poetess': 399,
#  'who': 400,
#  'wrote': 401,
#  'book': 402,
#  'verses': 403,
#  'wampum': 404,
#  'call': 405,
#  'complain': 406,
#  'just': 407,
#  'gets': 408,
#  'bedeviled': 409,
#  'can': 410,
#  'fall': 411,
#  'keep': 412,
#  'abouncing': 413,
#  'empty': 414,
#  'temples': 415,
#  'graves': 416,
#  'note': 417,
#  'unruffled': 418,
#  'repeatedly': 419,
#  'strove': 420,
#  'mebbe': 421,
#  'im': 422,
#  'wrong': 423,
#  'turrettops': 424,
#  'given': 425,
#  'bewitched': 426,
#  'last': 427,
#  'longer': 428,
#  'were': 429,
#  'seven': 430,
#  'cross': 431,
#  'lots': 432,
#  'walls': 433,
#  'everything': 434,
#  'now': 435,
#  'air': 436,
#  'ride': 437,
#  'other': 438,
#  'look': 439,
#  'box': 440,
#  'put': 441,
#  'away': 442,
#  'stillgoing': 443,
#  'every': 444,
#  'joints': 445,
#  'ye': 446,
#  'deliverers': 447,
#  'athens': 448,
#  'shame': 449,
#  'zealous': 450,
#  'ones': 451,
#  'laborious': 452,
#  'device': 453,
#  'eden': 454,
#  'sank': 455,
#  'grief': 456,
#  'seemed': 457,
#  'poetesss': 458,
#  'poems': 459,
#  'winds': 460,
#  'might': 461,
#  'rouse': 462,
#  'hangs': 463,
#  'chains': 464,
#  'pearl': 465,
#  'hermon': 466,
#  'seraph': 467,
#  'spread': 468,
#  'pinion': 469,
#  'came': 470,
#  'coasting': 471,
#  'child': 472,
#  'ancestral': 473,
#  'memories': 474,
#  'together': 475,
#  'halfpast': 476,
#  'three': 477,
#  'storm': 478,
#  'old': 479,
#  'song': 480,
#  'wild': 481,
#  'colonial': 482,
#  'boy': 483,
#  'tempt': 484,
#  'waters': 485,
#  'weeks': 486,
#  'incredulous': 487,
#  'luck': 488,
#  'ever': 489,
#  'again': 490,
#  'beloved': 491,
#  'heroes': 492,
#  'your': 493,
#  'deathless': 494,
#  'souls': 495,
#  'roam': 496,
#  'knew': 497,
#  'place': 498,
#  'kinsman': 499,
#  'skulls': 500,
#  'rogers': 501,
#  'rangers': 502,
#  'acquainted': 503,
#  'youre': 504,
#  'sunshine': 505,
#  'drawn': 506,
#  'passport': 507,
#  'branch': 508,
#  'failed': 509,
#  'find': 510,
#  'force': 511,
#  'strait': 512,
#  'shatter': 513,
#  'inward': 514,
#  'unswept': 515,
#  'floors': 516,
#  'tottering': 517,
#  'above': 518,
#  'creaking': 519,
#  'buggy': 520,
#  'load': 521,
#  'grain': 522,
#  'sleep': 523,
#  'dream': 524,
#  'till': 525,
#  'day': 526,
#  'sorry': 527,
#  'steered': 528,
#  'really': 529,
#  'straight': 530,
#  'journey': 531,
#  'among': 532,
#  'unearthed': 533,
#  'potatoes': 534,
#  'standing': 535,
#  'bright': 536,
#  'idea': 537,
#  'deareye': 538,
#  'beyond': 539,
#  'god': 540,
#  'secret': 541,
#  'held': 542,
#  'wings': 543,
#  'until': 544,
#  'trailed': 545,
#  'dust': 546,
#  'below': 547,
#  'roared': 548,
#  'brook': 549,
#  'hidden': 550,
#  'thoughts': 551,
#  'palsied': 552,
#  'sere': 553,
#  'cannot': 554,
#  'write': 555,
#  'speak': 556,
#  'think': 557,
#  'listening': 558,
#  'things': 559,
#  'fate': 560,
#  'whose': 561,
#  'also': 562,
#  'sorrow': 563,
#  'mighty': 564,
#  'wasnt': 565,
#  'anyone': 566,
#  'could': 567,
#  'grace': 568,
#  'did': 569,
#  'guide': 570,
#  'smell': 571,
#  'wet': 572,
#  'feathers': 573,
#  'heat': 574,
#  'sorrowfully': 575,
#  'new': 576,
#  'fountains': 577,
#  'overflow': 578,
#  'unfettered': 579,
#  'faster': 580,
#  'slower': 581,
#  'chanced': 582,
#  'pit': 583,
#  'starks': 584,
#  'digged': 585,
#  'havent': 586,
#  'stifling': 587,
#  'hot': 588,
#  'sap': 589,
#  'trembling': 590,
#  'wire': 591,
#  'stopping': 592,
#  'arent': 593,
#  'afraid': 594,
#  'whats': 595,
#  'gun': 596,
#  'much': 597,
#  'help': 598,
#  'tangle': 599,
#  'withered': 600,
#  'weeds': 601,
#  'hear': 602,
#  'voices': 603,
#  'hillside': 604,
#  'sun': 605,
#  'didnt': 606,
#  'nights': 607,
#  'year': 608,
#  'mowing': 609,
#  'field': 610,
#  'am': 611,
#  'going': 612,
#  'position': 613,
#  'close': 614,
#  'untidy': 615,
#  'save': 616,
#  'paused': 617,
#  'looked': 618,
#  'watched': 619,
#  'forty': 620,
#  'cellar': 621,
#  'holes': 622,
#  'struck': 623,
#  'hard': 624,
#  'bottom': 625,
#  'someone': 626,
#  'blew': 627,
#  'icy': 628,
#  'crust': 629,
#  'strange': 630,
#  'muffled': 631,
#  'caught': 632,
#  'silver': 633,
#  'lizard': 634,
#  'tail': 635,
#  'upon': 636,
#  'along': 637,
#  'alas': 638,
#  'feel': 639,
#  'tis': 640,
#  'feeling': 641,
#  'good': 642,
#  'kept': 643,
#  'cold': 644,
#  'isle': 645,
#  'fairest': 646,
#  'flowers': 647,
#  'guess': 648,
#  'estelle': 649,
#  'filled': 650,
#  'purse': 651,
#  'smart': 652,
#  'pair': 653,
#  'pumps': 654,
#  'beading': 655,
#  'clouds': 656,
#  'low': 657,
#  'trailing': 658,
#  'moments': 659,
#  'rain': 660,
#  'misted': 661,
#  'budded': 662,
#  'boughs': 663,
#  'piled': 664,
#  'enough': 665,
#  'yourself': 666,
#  'seek': 667,
#  'shelter': 668,
#  'happier': 669,
#  'star': 670,
#  'discordant': 671,
#  'melody': 672,
#  'wheres': 673,
#  'pallor': 674,
#  'strangely': 675,
#  'mistrust': 676,
#  'posies': 677,
#  'inner': 678,
#  'windowsill': 679,
#  'stark': 680,
#  'tumultuous': 681,
#  'sea': 682,
#  'crystal': 683,
#  'palace': 684,
#  'london': 685,
#  'imported': 686,
#  'bead': 687,
#  'water': 688,
#  'less': 689,
#  'converging': 690,
#  'slides': 691,
#  'avalanches': 692,
#  'hearts': 693,
#  'passion': 694,
#  'tone': 695,
#  'turned': 696,
#  'repented': 697,
#  'back': 698,
#  'ecstasies': 699,
#  'hell': 700,
#  'knees': 701,
#  'done': 702,
#  'hellforleather': 703,
#  'fever': 704,
#  'moonbeam': 705,
#  'pendulous': 706,
#  'yard': 707,
#  'headed': 708,
#  'for—': 709,
#  'stars': 710,
#  'whence': 711,
#  'forth': 712,
#  'height': 713,
#  'adventure': 714,
#  'fathers': 715,
#  'side': 716,
#  'seems': 717,
#  'lipbegotten': 718,
#  'words': 719,
#  'detail': 720,
#  'burned': 721,
#  'dissolved': 722,
#  'broken': 723,
#  'off': 724,
#  'woo': 725,
#  'picking': 726,
#  'faded': 727,
#  'blue': 728,
#  'virgin': 729,
#  'earth': 730,
#  'gave': 731,
#  'instant': 732,
#  'queenly': 733,
#  'lily': 734,
#  'adown': 735,
#  'dale': 736,
#  'entertain': 737,
#  'reconnoitre': 738,
#  'made': 739,
#  'sweetly': 740,
#  'scintillant': 741,
#  'stock': 742,
#  'counts': 743,
#  'ideals': 744,
#  'takes': 745,
#  'worth': 746,
#  'ill': 747,
#  'apple': 748,
#  'shadow': 749,
#  'perfect': 750,
#  'bliss': 751,
#  'wanted': 752,
#  'try': 753,
#  'noise': 754,
#  'misty': 755,
#  'mid': 756,
#  'region': 757,
#  'weir': 758,
#  'hands—': 759,
#  'hurt': 760,
#  'poem': 761,
#  'uplifted': 762,
#  'halted': 763,
#  'headless': 764,
#  'aftermath': 765,
#  'dim': 766,
#  'lake': 767,
#  'auber': 768,
#  'achilles': 769,
#  'diomed': 770,
#  'rest': 771,
#  'buds': 772,
#  'are': 773,
#  'bloom': 774,
#  'youth': 775,
#  'known': 776,
#  'whom': 777,
#  'passed': 778,
#  'each': 779,
#  'grassy': 780,
#  'wear': 781,
#  'make': 782,
#  'cheering': 783,
#  'few': 784,
#  'peckerfretted': 785,
#  'little': 786,
#  'hurried': 787,
#  'sweet': 788,
#  'talkedof': 789,
#  'mystery': 790,
#  'matter': 791,
#  'far': 792,
#  'times': 793,
#  'safely': 794,
#  'trust': 795,
#  'gleaming': 796,
#  'redlitten': 797,
#  'windows': 798,
#  'dank': 799,
#  'tarn': 800,
#  'united': 801,
#  'strengths': 802,
#  'upturned': 803,
#  'thousand': 804,
#  'loveless': 805,
#  'flock': 806,
#  'friends': 807,
#  'furthest': 808,
#  'bodies': 809,
#  'tell': 810,
#  'plagued': 811,
#  'death': 812,
#  'sometimes': 813,
#  'present': 814,
#  'pathway': 815,
#  'part': 816,
#  'spell': 817,
#  'motionless': 818,
#  'golden': 819,
#  'waiting': 820,
#  'chill': 821,
#  'effect': 822,
#  'most': 823,
#  'immemorial': 824,
#  'furniture': 825,
#  'lofty': 826,
#  'original': 827,
#  'rage': 828,
#  'weep': 829,
#  'glad': 830,
#  'happen': 831,
#  'prefer': 832,
#  'shine': 833,
#  'us': 834,
#  'remember': 835,
#  'rightly': 836,
#  'sprung': 837,
#  'thing': 838,
#  'liking': 839,
#  'about': 840,
#  'almost': 841,
#  'moment': 842,
#  'opening': 843,
#  'foreign': 844,
#  'soft': 845,
#  'dissyllables': 846,
#  'first': 847,
#  'impulse': 848,
#  'knob': 849,
#  'venuses': 850,
#  'unextinguished': 851,
#  'across': 852,
#  'quickening': 853,
#  'doth': 854,
#  'pass': 855,
#  'throats': 856,
#  'viola': 857,
#  'follow': 858,
#  'bought': 859,
#  'paid': 860,
#  'beads': 861,
#  'ruler': 862,
#  'realm': 863,
#  'seen': 864,
#  'lo': 865,
#  'hath': 866,
#  'reard': 867,
#  'throne': 868,
#  'wander': 869,
#  'beaten': 870,
#  'ways': 871,
#  'protection': 872,
#  'creases': 873,
#  'level': 874,
#  'waves': 875,
#  'bells': 876,
#  'dimremembered': 877,
#  'story': 878,
#  'woe': 879,
#  'yet': 880,
#  'sublime': 881,
#  'hope': 882,
#  'any': 883,
#  'toffile': 884,
#  'died': 885,
#  'jupiter': 886,
#  'lantern': 887,
#  'rattle': 888,
#  'yawning': 889,
#  'lenses': 890,
#  'harm': 891,
#  'luminous': 892,
#  'cool': 893,
#  'wearing': 894,
#  'deep': 895,
#  'crown': 896,
#  'sitting': 897,
#  'fireweed': 898,
#  'loving': 899,
#  'woods': 900,
#  'burnt': 901,
#  'sink': 902,
#  'under': 903,
#  'man': 904,
#  'wife': 905,
#  'heard': 906,
#  'upstairs': 907,
#  'bedroom': 908,
#  'sadly': 909,
#  'legended': 910,
#  'tomb': 911,
#  'saddest': 912,
#  'city': 913,
#  'lane': 914,
#  'bring': 915,
#  'broadboard': 916,
#  'paneling': 917,
#  'fresh': 918,
#  'recent': 919,
#  'axe': 920,
#  'crowd': 921,
#  'around': 922,
#  'earthly': 923,
#  'hour': 924,
#  'bid': 925,
#  'dropped': 926,
#  'unwilling': 927,
#  'explain': 928,
#  'slap': 929,
#  'sulphurous': 930,
#  'currents': 931,
#  'yaanek': 932,
#  'gems': 933,
#  'despite': 934,
#  'lion': 935,
#  'wall': 936,
#  'stands': 937,
#  'bare': 938,
#  'difference': 939,
#  'mans': 940,
#  'affairs': 941,
#  'interrupted': 942,
#  'cry': 943,
#  'tasted': 944,
#  'desire': 945,
#  'word': 946,
#  'round': 947,
#  'written': 948,
#  'sister': 949,
#  'ah': 950,
#  'mourn': 951,
#  'morrow': 952,
#  'foot': 953,
#  'without': 954,
#  'avail': 955,
#  'nation': 956,
#  'quick': 957,
#  'slammed': 958,
#  'burden': 959,
#  'body': 960,
#  'arthur': 961,
#  'amy': 962,
#  'wildest': 963,
#  'mount': 964,
#  'horse': 965,
#  'wonder': 966,
#  'hurry': 967,
#  'unhitch': 968,
#  'tears': 969,
#  'cosmic': 970,
#  'motes': 971,
#  'helpless': 972,
#  'hast': 973,
#  'thou': 974,
#  'dragged': 975,
#  'diana': 976,
#  'car': 977,
#  'ulalume': 978,
#  'farm': 979,
#  'springs': 980,
#  'dialect': 981,
#  'voice': 982,
#  'flying': 983,
#  'bird': 984,
#  'silent': 985,
#  'flight': 986,
#  'counting': 987,
#  'dinners': 988,
#  'built': 989,
#  'baptismal': 990,
#  'font': 991,
#  'manages': 992,
#  'upper': 993,
#  'remaining': 994,
#  'aster': 995,
#  'flower': 996,
#  'sought': 997,
#  'precipitate': 998,
#  'streams': 999,
#  ...}

# %%
len(word2idx)
# Out:
# 2524

# %%
# convert data into integer format
train_text_int = []
test_text_int = []

for text in train_text:
    tokens = text.split()
    line_as_int = [word2idx[token] for token in tokens]
    train_text_int.append(line_as_int)
    
for text in test_text:
    tokens = text.split()
    line_as_int = [word2idx.get(token, 0) for token in tokens]
    test_text_int.append(line_as_int)

# %%
train_text_int[100:105]
# Out:
# [[385, 1, 386, 172, 387, 388],
#  [31, 116, 389, 390],
#  [136, 391, 94, 69, 392, 59, 393],
#  [1, 394, 17, 1, 395, 59, 1, 396],
#  [1, 397, 20, 119, 36, 398, 20]]

# %%
# initialize A and pi matrices - for both classes
V = len(word2idx)

A0 = np.ones((V, V))
pi0 = np.ones(V)

A1 = np.ones((V, V))
pi1 = np.ones(V)

# %%
# compute counts for A and pi
def compute_counts(text_as_int, A, pi):
    for tokens in text_as_int:
        last_idx = None
        for idx in tokens:
            if last_idx is None:
                # it's the first word in a sentence
                pi[idx] += 1
            else:
                # the last word exists, so count a transition
                A[last_idx, idx] += 1
                
            # update last idx
            last_idx = idx

# %%
compute_counts([t for t, y in zip(train_text_int, y_train) if y == 0], A0, pi0)
compute_counts([t for t, y in zip(train_text_int, y_train) if y == 1], A1, pi1)

# %%
# normalize A and pi so they are valid probability matrices
# convince yourself that this is equivalent to the formulas shown before
A0 /= A0.sum(axis = 1, keepdims = True)
pi0 /= pi0.sum()

A1 /= A1.sum(axis = 1, keepdims = True)
pi1 /= pi1.sum()

# %%
# log A and pi since we don't need the actual probabilities
logA0 = np.log(A0)
logpi0 = np.log(pi0)

logA1 = np.log(A1)
logpi1 = np.log(pi1)

# %%
# compute priors

count0 = sum(y == 0 for y in y_train)
count1 = sum(y == 1 for y in y_train)

total = len(y_train)

p0 = count0 / total
p1 = count1 / total

logp0 = np.log(p0)
logp1 = np.log(p1)

p0, p1
# Out:
# (0.3306501547987616, 0.6693498452012384)

# %%
# build a classifier
class Classifier:
    def __init__(self, logAs, logpis, logpriors):
        self.logAs = logAs
        self.logpis = logpis
        self.logpriors = logpriors
        self.K = len(logpriors)
        
    def compute_log_likelihood(self, input_, class_):
        logA = self.logAs[class_]
        logpi = self.logpis[class_]
        
        last_idx = None
        logprob = 0
        
        for idx in input_:
            if last_idx is None:
                # it's the first token
                logprob += logpi[idx]
            else:
                logprob += logA[last_idx, idx]
                
            # update last_idx
            last_idx = idx
            
        return logprob
    
    def predict(self, inputs):
        predictions = np.zeros(len(inputs))
        for i, input_ in enumerate(inputs):
            posteriors = [self.compute_log_likelihood(input_, c) + self.logpriors[c] \
                         for c in range(self.K)]
            pred = np.argmax(posteriors)
            predictions[i] = pred
            
            return predictions

# %%
clf = Classifier([logA0, logA1], [logpi0, logpi1], [logp0, logp1])

# %%
Ptrain = clf.predict(train_text_int)
print(f"Train acc: {np.mean(Ptrain == y_train)}")
# Out:
# Train acc: 0.33126934984520123

# %%
Ptest = clf.predict(test_text_int)
print(f"Train acc: {np.mean(Ptest == y_test)}")
# Out:
# Train acc: 0.3432282003710575

# %%
from sklearn.metrics import confusion_matrix, f1_score

# %%
cm = confusion_matrix(y_train, Ptrain)
cm
# Out:
# array([[ 534,    0],
#        [1080,    1]])

# %%
cm_test = confusion_matrix(y_test, Ptest)
cm_test
# Out:
# array([[184,   0],
#        [354,   1]])

# %%
f1_score(y_train, Ptrain)
# Out:
# 0.0018484288354898338

# %%
f1_score(y_test, Ptest)
# Out:
# 0.005617977528089888
